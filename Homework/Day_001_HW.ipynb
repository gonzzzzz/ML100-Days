# %% [markdown]
# # 作業1：

# %% [markdown]
# ### [鐵達尼號](https://www.kaggle.com/c/titanic#evaluation)
# ### 1. 你選的這組資料為何重要
# ### Predict if a passenger survived the sinking of the Titanic or not, and to have better safety regulations for ships.
# ### 2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# ### Based on historical data.
# ### 3. 蒐集而來的資料型態為何
# ### Provide outcome for each passenger and  features like passengers's gender and class.
# ### 4.這組資料想解決的問題如何評估
# ### Use metric such as confusion confusion matrix and accuracy.

# %% [markdown]
# # 作業2：
# ### 1.核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# ### 分析資料來調漲價格，吸引更多司機上街的需求
# ### 2.資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# ### 由 app 收集各種資料，例如:時間、地點、行進距離
# ### 3. 蒐集而來的資料型態為何
# ### 結構化資料
# ### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# ### 藉由事前機率及條件機率預測乘客呼叫司機的機率，機率越低在價格上會調較高的權重。事後機率可以與過去實際資料做比對。

# %% [markdown]
# # 作業三

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,y_hat):
    MSE=((y-y_hat)**2).mean()
    #sum((y-y_hat)**2)/len(y))
    return MSE

# %%
def mean_absolute_error(y, y_hat):
    MAE = sum(abs(y - y_hat)) / len(y)
    return MAE

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 195.392
# The Mean absolute error is 11.419
